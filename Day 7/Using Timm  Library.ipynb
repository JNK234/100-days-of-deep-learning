# %% [markdown]
# # Getting started with timm library
#
# `timm` is a deep-learning library created by Ross Wightman and is a collection of SOTA computer vision models, layers, utilities, optimizers, schedulers, data-loaders, augmentations and also training/validating scripts with ability to reproduce ImageNet training results.

# %% [markdown]
# Now let's see how to make use the pretrained models with fastai and train a classifier.

# %% [markdown]
# ## Installation

# %% [markdown]
# We can install the `timm` library from pip:

# %% [markdown]
# `pip install timm`

# %% [markdown]
# Or we can directly install it from github source for more updated version:

# %% [markdown]
# `pip install git+https://github.com/rwightman/pytorch-image-models.git`

# %% [markdown]
# Now let's get started and see how to load the model from timm and use it with fastai

# %%
# !pip install timm -q

# %% [markdown]
# ## Getting Started

# %% [markdown]
# Now let's import the necessary libraries,

# %%
from fastai.vision.all import *

import timm

# %% [markdown]
# Now let's download the `PETS` dataset,

# %%
path = untar_data(URLs.PETS)

# %%
path = (path/'images')

# %%
path.ls()
# Out:
# (#7393) [Path('/home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/Siamese_87.jpg'),Path('/home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/chihuahua_126.jpg'),Path('/home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/german_shorthaired_97.jpg'),Path('/home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/Bombay_157.jpg'),Path('/home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/Bengal_12.jpg'),Path('/home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/japanese_chin_116.jpg'),Path('/home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/havanese_109.jpg'),Path('/home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/scottish_terrier_122.jpg'),Path('/home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_146.jpg'),Path('/home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/boxer_176.jpg')...]

# %% [markdown]
# Before creating the datablock let's see some info about the dataset i.e. the Pets dataset has almost 7.4k images of 37 breeds of cats and dogs. But now let's just train a cat vs dog classifier.

# %% [markdown]
# ## Create Datablock and Dataloaders

# %% [markdown]
# First let's see some images and create the dataloaders

# %%
print("Path: ", path.ls()[1])
img = PILImage.create(path.ls()[1])
img.show()
# Out:
# Path:  /home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/chihuahua_126.jpg
# <AxesSubplot:>

# %%
print("Path: ", path.ls()[0])
img = PILImage.create(path.ls()[0])
img.show()
# Out:
# Path:  /home/studio-lab-user/.fastai/data/oxford-iiit-pet/images/Siamese_87.jpg
# <AxesSubplot:>

# %% [markdown]
# We can see that all the names of dog images in this datasset start with a lowercase letter and names of cat images start with uppercase letter.

# %%
def get_label(x):
    if x.name[0].isupper():
        return 'Cat'
    else:
        return 'Dog'

# %% [markdown]
# By using the above function, we can now label every image

# %% [markdown]
# Now create the datablock,

# %%
pets = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    get_y=get_label,
    splitter=RandomSplitter(seed=42),
    item_tfms=Resize(420),
    batch_tfms=[*aug_transforms(size=224, min_scale=0.5),
                Normalize.from_stats(*imagenet_stats)]
)

# %%
dls = pets.dataloaders(path, bs=32)
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torch/_tensor.py:1051: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   ret = func(*args, **kwargs)

# %%
dls.show_batch()

# %% [markdown]
# ## Using Timm library

# %% [markdown]
# The `Timm` library consists of different state-of-the-art models with pretrained wights. Now let's see how to use them.

# %% [markdown]
# We can get the list of the models by using : `timm.list_models()`

# %%
timm.list_models()[:10]
# Out:
# ['adv_inception_v3',
#  'bat_resnext26ts',
#  'botnet26t_256',
#  'botnet50ts_256',
#  'cait_m36_384',
#  'cait_m48_448',
#  'cait_s24_224',
#  'cait_s24_384',
#  'cait_s36_384',
#  'cait_xs24_384']

# %%
print("Number of available model: ",len(timm.list_models()))
# Out:
# Number of available model:  612

# %% [markdown]
# That's golden.. There are 612 pretrained models

# %% [markdown]
# Now let' create a model using `create_model()` method.

# %%
model = timm.create_model('efficientnet_b3a', pretrained=True, num_classes=1).cuda()

# %% [markdown]
# In the above line we have created an `efficientnet_b3a` model with pretrained weights and have replaced the head with the number of output nodes in our dataset i.e 1. (Since it is binary classification)

# %% [markdown]
# Let's check the dimensions of the inputs, targets and model activations.

# %%
x,y = dls.one_batch()

# %%
x.shape, y.shape
# Out:
# (torch.Size([32, 3, 224, 224]), torch.Size([32]))

# %%
dls.vocab
# Out:
# ['Cat', 'Dog']

# %% [markdown]
# ## Model training

# %% [markdown]
# Now let's create the `Learner` object with dataloader and model.

# %%
learn = Learner(dls, model, loss_func=BCEWithLogitsLossFlat(), metrics=accuracy)

# %% [markdown]
# Now let's find the learning rate and train the model

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=9.120108734350652e-05)

# %%
learn.fit_one_cycle(5, lr_max=1e-4)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [3/5 04:25<02:56]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.332003</td>
#       <td>0.101814</td>
#       <td>0.322057</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.103348</td>
#       <td>0.039152</td>
#       <td>0.322057</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.068146</td>
#       <td>0.575195</td>
#       <td>0.322057</td>
#       <td>01:28</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='184' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       3.80% [7/184 00:03<01:35 0.0660]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1102/3872457857.py in <module>
# ----> 1 learn.fit_one_cycle(5, lr_max=1e-4)
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/callback/schedule.py in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt)
#     114     scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max/div_final),
#     115               'mom': combined_cos(pct_start, *(self.moms if moms is None else moms))}
# --> 116     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd)
#     117
#     118 # Cell
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     219             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     220             self.n_epoch = n_epoch
# --> 221             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     222
#     223     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in _do_fit(self)
#     210         for epoch in range(self.n_epoch):
#     211             self.epoch=epoch
# --> 212             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     213
#     214     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False):
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in _do_epoch(self)
#     204
#     205     def _do_epoch(self):
# --> 206         self._do_epoch_train()
#     207         self._do_epoch_validate()
#     208
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in _do_epoch_train(self)
#     196     def _do_epoch_train(self):
#     197         self.dl = self.dls.train
# --> 198         self._with_events(self.all_batches, 'train', CancelTrainException)
#     199
#     200     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in all_batches(self)
#     167     def all_batches(self):
#     168         self.n_iter = len(self.dl)
# --> 169         for o in enumerate(self.dl): self.one_batch(*o)
#     170
#     171     def _do_one_batch(self):
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in one_batch(self, i, b)
#     192         b = self._set_device(b)
#     193         self._split(b)
# --> 194         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     195
#     196     def _do_epoch_train(self):
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in _do_one_batch(self)
#     179         self('before_backward')
#     180         self.loss_grad.backward()
# --> 181         self._with_events(self.opt.step, 'step', CancelStepException)
#     182         self.opt.zero_grad()
#     183
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     161
#     162     def _with_events(self, f, event_type, ex, final=noop):
# --> 163         try: self(f'before_{event_type}');  f()
#     164         except ex: self(f'after_cancel_{event_type}')
#     165         self(f'after_{event_type}');  final()
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/optimizer.py in step(self)
#      80     def step(self):
#      81         for p,pg,state,hyper in self.all_params(with_grad=True):
# ---> 82             for cb in self.cbs: state = _update(state, cb(p, **{**state, **hyper}))
#      83             self.state[p] = state
#      84
#
# ~/.conda/envs/default/lib/python3.9/site-packages/fastai/optimizer.py in adam_step(p, lr, mom, step, sqr_mom, grad_avg, sqr_avg, eps, **kwargs)
#     177     debias1 = debias(mom,     1-mom,     step)
#     178     debias2 = debias(sqr_mom, 1-sqr_mom, step)
# --> 179     p.data.addcdiv_(grad_avg, (sqr_avg/debias2).sqrt() + eps, value = -lr / debias1)
#     180     return p
#     181
#
# KeyboardInterrupt:

# %% [markdown]
# Woah... Our model has done a good job and was able to achive 99% accuracy on the pets dataset.

# %% [markdown]
# ## Inference

# %% [markdown]
# Now let's get some predictions from the validation dataset

# %%
interep = ClassificationInterpretation.from_learner(learn)

# %%
interep.print_classification_report()
